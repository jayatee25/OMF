# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

np.random.seed(143)

# %%
stock_price = pd.read_csv("stock_data_2_yrs_daywise.csv")
stock_price.set_index('Date', inplace = True)

returns = (stock_price - stock_price.shift(1))/stock_price.shift(1)
returns.dropna(inplace = True)
returns.head()
# Out:
#            AdaniPorts    Ambuja    Apollo  AxisBank     Bajaj       BoB  \
# Date
# 01-Sep-23   -0.027492 -0.018092  0.007811 -0.018739  0.002547 -0.019895
# 31-Aug-23    0.029038  0.039667  0.012918  0.009138 -0.030779  0.024038
# 30-Aug-23    0.030337 -0.002032  0.004464 -0.001831 -0.015114  0.000261
# 29-Aug-23   -0.022914 -0.007691 -0.005333  0.010091  0.005899 -0.007823
# 28-Aug-23    0.006621 -0.005471 -0.006255 -0.008073 -0.007937 -0.001051
#
#                Bata  BlueStar    Camlin   Castrol  ...  SteelAuth  sunPharma  \
# Date                                               ...
# 01-Sep-23 -0.001284 -0.004227 -0.000662  0.019359  ...  -0.066243   0.001982
# 31-Aug-23 -0.010797  0.003976  0.006623 -0.012086  ...   0.006699  -0.001079
# 30-Aug-23  0.000195 -0.006712 -0.030592  0.000699  ...  -0.033381   0.012511
# 29-Aug-23 -0.009419 -0.013447 -0.011876  0.014321  ...  -0.012527  -0.001244
# 28-Aug-23  0.005590 -0.035616 -0.016140 -0.000344  ...  -0.020571  -0.010413
#
#            TataComm  TataSteel     Titan  Ultramarine     Wipro  Wonderla  \
# Date
# 01-Sep-23 -0.037178  -0.042685 -0.001284    -0.001129 -0.026376  0.018740
# 31-Aug-23  0.002812  -0.005270 -0.010797    -0.037288  0.002463  0.002290
# 30-Aug-23 -0.007718  -0.020782  0.000195     0.017488  0.004913  0.008350
# 29-Aug-23  0.023641  -0.013733 -0.009419     0.003461  0.000000 -0.009843
# 28-Aug-23 -0.006478  -0.013080  0.005590    -0.062651  0.006845 -0.001815
#
#             YesBank  Nilkamal
# Date
# 01-Sep-23 -0.030460  0.014803
# 31-Aug-23 -0.000593  0.019937
# 30-Aug-23  0.002966 -0.057087
# 29-Aug-23 -0.005914 -0.005775
# 28-Aug-23  0.005949 -0.009894
#
# [5 rows x 50 columns]

# %%
from scipy.optimize import minimize
r = np.array(returns)

exp_returns = r.mean(axis = 0)
std_dev = r.std(axis = 0)
cov_matrix = np.array(returns.cov())

# %%
def VarRisk_minimization(shortsell = True):
  def objective1(xi):
    return np.dot(xi.T, np.dot(cov_matrix, xi))
  def objective2(xi):
    return np.dot(xi.T, exp_returns).sum()
  objective = lambda xi: 0.5*objective1(xi) - 0.5*objective2(xi) #weighted sum = 0.5
  initial_weights = [1/50]*50
  constraints = [
      {'type': 'eq', 'fun': lambda w: sum(w) - 1, 'args': ()},
      # {'type': 'ineq', 'fun': lambda w: sum(w*exp_returns) - target_return}
  ]
  if not shortsell:
    bounds = [(0., None)]*(len(initial_weights))
    result = minimize(objective, initial_weights, constraints = constraints, bounds = bounds)
  else:
    result = minimize(objective, initial_weights, constraints = constraints)
  return result.x

# %%
def risk_return(weights):
  risk = np.dot(weights.T, np.dot(cov_matrix, weights))
  returns = np.dot(weights.T, exp_returns)
  return risk, returns

# %%
results = VarRisk_minimization(True)
total_capital = 100000
investment = pd.DataFrame(results*total_capital)

cols = returns.columns
investment.set_index(cols, inplace = True)

# %%
investment['Investment'] = investment[0]
investment.drop([0],axis = 1, inplace = True)
investment.round(3)
# Out:
#                  Investment
# AdaniPorts        94074.387
# Ambuja            74141.319
# Apollo          -128057.386
# AxisBank         -28097.387
# Bajaj             15184.184
# BoB             -130552.271
# Bata            -107578.120
# BlueStar          44477.798
# Camlin           -90574.375
# Castrol          125427.460
# Cipla             30938.393
# Deccan Gold      -26948.710
# GreavesCotton     62256.917
# Fortis             8250.969
# Glenmark          55858.452
# GodfreyPhillips  -53988.156
# Godrej           145944.937
# HCLTech          -79296.097
# HDFCbank          65303.592
# Hindalco          -6370.754
# HindustanPetrol  168527.802
# Imagica          -34834.245
# Infosys           45860.117
# IRCTC             10583.840
# ITC             -232462.700
# Kajaria           17648.202
# Kalyan           -74948.506
# Linc             -17622.686
# Lux              243965.291
# Max              -23330.565
# AndhraPaper      -83625.889
# Nerolac          133926.418
# ONGC            -119325.671
# Panasonic         10367.936
# Patanjali         47143.835
# Timex            -53073.541
# Raymond         -127203.355
# Reliance          51766.746
# Siemens         -101213.429
# SBI               40283.176
# SteelAuth        190399.563
# sunPharma       -124132.398
# TataComm         -46802.289
# TataSteel          4768.327
# Titan           -107578.127
# Ultramarine       11719.741
# Wipro            120386.663
# Wonderla         -36485.951
# YesBank           41683.389
# Nilkamal          73213.152

# %%
w1 = VarRisk_minimization(True)
risk_return(w1)
# Out:
# (0.016789432839753395, 0.033040269595241735)

# %%
def MADRisk_minimization(shortsell = True):
  def objective1(xi):
    return (np.abs(((r - exp_returns)*xi)).sum(axis = 1)).sum()/r.shape[0]
  def objective2(xi):
    return np.dot(xi.T, exp_returns).sum()
  objective = lambda xi: 0.5*objective1(xi) - 0.5*objective2(xi) #weighted sum = 0.5
  initial_weights = [1/50]*50
  constraints = [
      {'type': 'eq', 'fun': lambda w: sum(w) - 1, 'args': ()},
      # {'type': 'ineq', 'fun': lambda w: sum(exp_returns*w) - target_return}
  ]
  if not shortsell:
    bounds = [(0., None)]*(len(initial_weights))
    result = minimize(objective, initial_weights, constraints = constraints, bounds = bounds)
  else:
    result = minimize(objective, initial_weights, constraints = constraints)
  return result.x

# %%
result_MAD = MADRisk_minimization(True)
total_capital = 100000
investment = pd.DataFrame(result_MAD*total_capital)

cols = returns.columns
investment.set_index(cols, inplace = True)

investment['Investment'] = investment[0]
investment.drop([0],axis = 1, inplace = True)
investment.round(3)
# Out:
#                  Investment
# AdaniPorts          -42.311
# Ambuja               44.106
# Apollo              -18.464
# AxisBank           5280.937
# Bajaj                12.711
# BoB                  38.748
# Bata                 12.592
# BlueStar             51.020
# Camlin               38.110
# Castrol            7369.935
# Cipla             10957.682
# Deccan Gold          23.826
# GreavesCotton         4.136
# Fortis               -0.338
# Glenmark             22.065
# GodfreyPhillips       8.914
# Godrej               -0.667
# HCLTech            3500.222
# HDFCbank          16588.140
# Hindalco             -2.900
# HindustanPetrol      25.074
# Imagica               2.655
# Infosys           11046.463
# IRCTC                -0.228
# ITC                7520.843
# Kajaria              16.105
# Kalyan                5.691
# Linc                 -7.974
# Lux                  48.636
# Max                  -1.146
# AndhraPaper          46.300
# Nerolac              40.140
# ONGC                  9.918
# Panasonic             8.077
# Patanjali             6.607
# Timex                -6.058
# Raymond              20.189
# Reliance           6266.472
# Siemens              65.403
# SBI                6200.449
# SteelAuth            48.580
# sunPharma          9737.217
# TataComm             -3.211
# TataSteel            14.085
# Titan                12.592
# Ultramarine           0.347
# Wipro             14909.725
# Wonderla              2.030
# YesBank              69.510
# Nilkamal              7.046

# %%
w2 = MADRisk_minimization(True)
risk_return(w2)
# Out:
# (8.380932175360959e-05, -0.00013790756031195178)

# %%
def MMRisk_minimization(shortsell = True):
  def objective1(xi):
    return np.max(np.abs(xi - exp_returns))
  def objective2(xi):
    return np.dot(xi.T, exp_returns).sum()
  objective = lambda xi: 0.5*objective1(xi) - 0.5*objective2(xi) #weighted sum = 0.5
  initial_weights = [1/50]*50
  constraints = [
      {'type': 'eq', 'fun': lambda w: sum(w) - 1, 'args': ()},
      # {'type': 'ineq', 'fun': lambda w: sum(w*exp_returns) - target_return}
  ]
  if not shortsell:
    bounds = [(0., None)]*(len(initial_weights))
    result = minimize(objective, initial_weights, constraints = constraints, bounds = bounds)
  else:
    result = minimize(objective, initial_weights, constraints = constraints)
  return result.x

# %%
result_MM = MMRisk_minimization(True)
total_capital = 100000
investment = pd.DataFrame(result_MM*total_capital)

cols = returns.columns
investment.set_index(cols, inplace = True)

investment['Investment'] = investment[0]
investment.drop([0],axis = 1, inplace = True)
investment.round(3)
# Out:
#                  Investment
# AdaniPorts         2103.194
# Ambuja             2093.926
# Apollo             1997.462
# AxisBank           2053.056
# Bajaj              2102.790
# BoB                1890.451
# Bata               2003.592
# BlueStar           2107.740
# Camlin             1949.262
# Castrol            2103.487
# Cipla              2063.491
# Deccan Gold        1993.670
# GreavesCotton      2105.806
# Fortis             2082.141
# Glenmark           2102.580
# GodfreyPhillips    1945.622
# Godrej             2104.379
# HCLTech            2083.541
# HDFCbank           2102.661
# Hindalco           2088.656
# HindustanPetrol    2105.470
# Imagica            1420.867
# Infosys            2104.182
# IRCTC              2138.435
# ITC                1850.241
# Kajaria            2057.624
# Kalyan             1657.150
# Linc               1765.758
# Lux                2113.420
# Max                1934.985
# AndhraPaper        1992.408
# Nerolac            2109.339
# ONGC               2024.760
# Panasonic          2103.319
# Patanjali          2105.311
# Timex              1543.161
# Raymond            1278.859
# Reliance           2092.458
# Siemens            1928.775
# SBI                2047.974
# SteelAuth          2106.547
# sunPharma          1985.711
# TataComm           2060.666
# TataSteel          2184.937
# Titan              2003.592
# Ultramarine        2089.421
# Wipro              2105.777
# Wonderla           1809.566
# YesBank            2098.174
# Nilkamal           2103.607

# %%
w3 = MMRisk_minimization(True)
risk_return(w3)
# Out:
# (0.0001857579506295628, 0.00022352436848140566)
